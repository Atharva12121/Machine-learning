# %%
import pandas as pd

# %%
df=pd.read_csv('age_premium_data.csv')

# %%
df
# Out:
#    Age  Premium
# 0   25    18000
# 1   30    32000
# 2   35    42000
# 3   40    47000
# 4   45    55000

# %%
x=df['Age']  #independent variable

# %%
x
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    45
# Name: Age, dtype: int64

# %%
y=df['Premium'] # depandent  variable

# %%
y
# Out:
# 0    18000
# 1    32000
# 2    42000
# 3    47000
# 4    55000
# Name: Premium, dtype: int64

# %%
# now split the data
from sklearn.model_selection import train_test_split

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,train_size=0.2) # 0.2 show that 20% data use for test else reamin 80% is use for train

# %%
x_train
# Out:
# 4    45
# 3    40
# 2    35
# 1    30
# Name: Age, dtype: int64

# %%
x_test
# Out:
# 0    25
# Name: Age, dtype: int64

# %%
y_train
# Out:
# 4    55000
# 3    47000
# 2    42000
# 1    32000
# Name: Premium, dtype: int64

# %%
y_test
# Out:
# 0    18000
# Name: Premium, dtype: int64
