# %%
import pandas as pd
from sklearn import linear_model

# %%
df=pd.read_csv('mutiple value.csv')

# %%
df
# Out:
#    Age  Height  Weight  Premium
# 0   25  162.56      70    18000
# 1   30  172.72      95    38000
# 2   35  167.64      78    38000
# 3   40     NaN     110    60000
# 4   45  157.48      85    70000

# %%
#reaplace missing varable
mean_height=df.Height.mean()

# %%
df.Height=df.Height.fillna(mean_height)

# %%
df
# Out:
#    Age  Height  Weight  Premium
# 0   25  162.56      70    18000
# 1   30  172.72      95    38000
# 2   35  167.64      78    38000
# 3   40  165.10     110    60000
# 4   45  157.48      85    70000

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['Age','Height','Weight']].values,df[['Premium']].values)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([[2150.26052416, -248.45851574,  312.65291961]])

# %%
reg.intercept_
# Out:
# array([-16827.01315482])

# %%
reg.predict([[27,167,60]])
# Out:
# array([[18496.62404572]])

# %%
# cross check y=m1*x1+m2*x2----+c
27*2150.26052416+167*-248.45851574+60*312.65291961-16827.01315482
# Out:
# 18496.624045519995

# %%
reg.predict([[60,187,90]])
# Out:
# array([[93865.63861639]])
