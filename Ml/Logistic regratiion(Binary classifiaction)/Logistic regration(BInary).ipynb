# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('Binary.csv')

# %%
dataset
# Out:
#     age bought_insurance
# 0    21               no
# 1    45              yes
# 2    32              yes
# 3    41              yes
# 4    20               no
# 5    35              yes
# 6    20               no
# 7    23               no
# 8    42              yes
# 9    34              yes
# 10   24               no
# 11   22               no
# 12   23               no
# 13   25               no
# 14   43              yes
# 15   44              yes
# 16   25               no
# 17   30              yes
# 18   31              yes

# %%
# now convert catogrial data to numeric data

# %%
dataset['bought_insurance'].replace({'no': '0', 'yes': '1'}, inplace=True)  #inplace use to  permanently covert the data

# %%
dataset
# Out:
#     age bought_insurance
# 0    21                0
# 1    45                1
# 2    32                1
# 3    41                1
# 4    20                0
# 5    35                1
# 6    20                0
# 7    23                0
# 8    42                1
# 9    34                1
# 10   24                0
# 11   22                0
# 12   23                0
# 13   25                0
# 14   43                1
# 15   44                1
# 16   25                0
# 17   30                1
# 18   31                1

# %%
# now we as to visualise the data in point
plt.scatter(x='age',y='bought_insurance',data=dataset)

# %%
#  now split the dataset for training and tessing
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(dataset[['age']],dataset[['bought_insurance']],test_size=0.2)

# %%
len(x_test)
# Out:
# 4

# %%
len(x_train)
# Out:
# 15

# %%
len(y_test)
# Out:
# 4

# %%
x_test
# Out:
#     age
# 4    20
# 0    21
# 5    35
# 17   30

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train) # fit is use when model ha0s to ready to fit and now we predict
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array(['0', '0', '1', '1'], dtype=object)

# %%
lr.predict([[18]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['0'], dtype=object)

# %%
lr.predict([[60]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['1'], dtype=object)
